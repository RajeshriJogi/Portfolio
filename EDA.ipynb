# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe(include = ["int64", "object"])
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df.drop("description", axis = 1, inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
constraint = df["cast"].apply(lambda x: str(x).split(",")).tolist()
df_cast = pd.DataFrame(constraint, index = df["title"])
df_cast = df_cast.stack()
df_cast = pd.DataFrame(df_cast.reset_index())
df_cast= df_cast.rename(columns = {0:"actors"})
df_cast.drop(["level_1"], axis = 1, inplace = True)

# %%
df_cast
# Out:
#                       title                  actors
# 0      Dick Johnson Is Dead                     nan
# 1             Blood & Water              Ama Qamata
# 2             Blood & Water             Khosi Ngema
# 3             Blood & Water           Gail Mabalane
# 4             Blood & Water          Thabang Molaba
# ...                     ...                     ...
# 64946                Zubaan        Manish Chaudhary
# 64947                Zubaan            Meghna Malik
# 64948                Zubaan           Malkeet Rauni
# 64949                Zubaan          Anita Shabdish
# 64950                Zubaan   Chittaranjan Tripathy
#
# [64951 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df_final = df_cast.merge(df[['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in']], on = ["title"], how = "left")
df_final
# Out:
#                       title                  actors show_id     type  \
# 0      Dick Johnson Is Dead                     nan      s1    Movie
# 1             Blood & Water              Ama Qamata      s2  TV Show
# 2             Blood & Water             Khosi Ngema      s2  TV Show
# 3             Blood & Water           Gail Mabalane      s2  TV Show
# 4             Blood & Water          Thabang Molaba      s2  TV Show
# ...                     ...                     ...     ...      ...
# 64946                Zubaan        Manish Chaudhary   s8807    Movie
# 64947                Zubaan            Meghna Malik   s8807    Movie
# 64948                Zubaan           Malkeet Rauni   s8807    Movie
# 64949                Zubaan          Anita Shabdish   s8807    Movie
# 64950                Zubaan   Chittaranjan Tripathy   s8807    Movie
#
#               director                                               cast  \
# ...

# %%
df_final.isnull().sum()
# Out:
# title               0
# actors              0
# show_id             0
# type                0
# director        19013
# cast              825
# country          5053
# date_added         69
# release_year        0
# rating             38
# duration            3
# listed_in           0
# dtype: int64

# %%
df_final["actors"].value_counts()
# Out:
# nan                       825
#  Anupam Kher               39
#  Rupa Bhimani              31
#  Takahiro Sakurai          30
#  Julie Tejwani             28
#                          ...
#  Vedika                     1
#  Tedros Teclebrhan          1
#  Maryam Zaree               1
#  Melanie Straub             1
#  Chittaranjan Tripathy      1
# Name: actors, Length: 39297, dtype: int64

# %%
constraint = df["director"].apply(lambda x: str(x).split(",")).tolist()
df_director = pd.DataFrame(constraint, index = df["title"])
df_director = df_director.stack()
df_director = pd.DataFrame(df_director.reset_index())
df_director= df_director.rename(columns = {0:"Director"})
df_director.drop(["level_1"], axis = 1, inplace = True)

# %%
df_director
# Out:
#                       title         Director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              nan
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              nan
# 4              Kota Factory              nan
# ...                     ...              ...
# 9607                 Zodiac    David Fincher
# 9608            Zombie Dumb              nan
# 9609             Zombieland  Ruben Fleischer
# 9610                   Zoom     Peter Hewitt
# 9611                 Zubaan      Mozez Singh
#
# [9612 rows x 2 columns]

# %%
df_final.columns
# Out:
# Index(['title', 'actors', 'show_id', 'type', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df_final.drop("cast",axis = 1, inplace = True)
df_final
# Out:
#                       title                  actors show_id     type  \
# 0      Dick Johnson Is Dead                     nan      s1    Movie
# 1             Blood & Water              Ama Qamata      s2  TV Show
# 2             Blood & Water             Khosi Ngema      s2  TV Show
# 3             Blood & Water           Gail Mabalane      s2  TV Show
# 4             Blood & Water          Thabang Molaba      s2  TV Show
# ...                     ...                     ...     ...      ...
# 64946                Zubaan        Manish Chaudhary   s8807    Movie
# 64947                Zubaan            Meghna Malik   s8807    Movie
# 64948                Zubaan           Malkeet Rauni   s8807    Movie
# 64949                Zubaan          Anita Shabdish   s8807    Movie
# 64950                Zubaan   Chittaranjan Tripathy   s8807    Movie
#
#               director        country          date_added  release_year  \
# ...

# %%
df_final.columns
# Out:
# Index(['title', 'actors', 'show_id', 'type', 'director', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df_final = df_director.merge(df_final[['title', 'actors', 'show_id', 'type', 'director', 'country',
       'date_added', 'release_year', 'rating', 'duration', 'listed_in']], on=["title"], how="left")

# %%
df_final
# Out:
#                       title         Director                  actors show_id  \
# 0      Dick Johnson Is Dead  Kirsten Johnson                     nan      s1
# 1             Blood & Water              nan              Ama Qamata      s2
# 2             Blood & Water              nan             Khosi Ngema      s2
# 3             Blood & Water              nan           Gail Mabalane      s2
# 4             Blood & Water              nan          Thabang Molaba      s2
# ...                     ...              ...                     ...     ...
# 70807                Zubaan      Mozez Singh        Manish Chaudhary   s8807
# 70808                Zubaan      Mozez Singh            Meghna Malik   s8807
# 70809                Zubaan      Mozez Singh           Malkeet Rauni   s8807
# 70810                Zubaan      Mozez Singh          Anita Shabdish   s8807
# 70811                Zubaan      Mozez Singh   Chittaranjan Tripathy   s8807
#
# ...

# %%
df_final.drop("director", axis = 1, inplace  = True)

# %%
df_final
# Out:
#                       title         Director                  actors show_id  \
# 0      Dick Johnson Is Dead  Kirsten Johnson                     nan      s1
# 1             Blood & Water              nan              Ama Qamata      s2
# 2             Blood & Water              nan             Khosi Ngema      s2
# 3             Blood & Water              nan           Gail Mabalane      s2
# 4             Blood & Water              nan          Thabang Molaba      s2
# ...                     ...              ...                     ...     ...
# 70807                Zubaan      Mozez Singh        Manish Chaudhary   s8807
# 70808                Zubaan      Mozez Singh            Meghna Malik   s8807
# 70809                Zubaan      Mozez Singh           Malkeet Rauni   s8807
# 70810                Zubaan      Mozez Singh          Anita Shabdish   s8807
# 70811                Zubaan      Mozez Singh   Chittaranjan Tripathy   s8807
#
# ...

# %%
constraint = df["country"].apply(lambda x: str(x).split(",")).tolist()
df_country = pd.DataFrame(constraint, index = df["title"])
df_country = df_country.stack()
df_country = pd.DataFrame(df_country.reset_index())
df_country= df_country.rename(columns = {0:"Country"})
df_country.drop(["level_1"], axis = 1, inplace = True)
df_country
# Out:
#                        title        Country
# 0       Dick Johnson Is Dead  United States
# 1              Blood & Water   South Africa
# 2                  Ganglands            nan
# 3      Jailbirds New Orleans            nan
# 4               Kota Factory          India
# ...                      ...            ...
# 10845                 Zodiac  United States
# 10846            Zombie Dumb            nan
# 10847             Zombieland  United States
# 10848                   Zoom  United States
# 10849                 Zubaan          India
#
# [10850 rows x 2 columns]

# %%
df_final.columns
# Out:
# Index(['title', 'Director', 'actors', 'show_id', 'type', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df_final = df_country.merge(df_final[['title', 'Director', 'actors', 'show_id', 'type', 'country',
       'date_added', 'release_year', 'rating', 'duration', 'listed_in']], on = ["title"], how="left")
df_final
# Out:
#                       title        Country         Director  \
# 0      Dick Johnson Is Dead  United States  Kirsten Johnson
# 1             Blood & Water   South Africa              nan
# 2             Blood & Water   South Africa              nan
# 3             Blood & Water   South Africa              nan
# 4             Blood & Water   South Africa              nan
# ...                     ...            ...              ...
# 89410                Zubaan          India      Mozez Singh
# 89411                Zubaan          India      Mozez Singh
# 89412                Zubaan          India      Mozez Singh
# 89413                Zubaan          India      Mozez Singh
# 89414                Zubaan          India      Mozez Singh
#
#                        actors show_id     type        country  \
# 0                         nan      s1    Movie  United States
# 1                  Ama Qamata      s2  TV Show   South Africa
# ...

# %%
df_final.drop("country", axis = 1, inplace = True)
df_final
# Out:
#                       title        Country         Director  \
# 0      Dick Johnson Is Dead  United States  Kirsten Johnson
# 1             Blood & Water   South Africa              nan
# 2             Blood & Water   South Africa              nan
# 3             Blood & Water   South Africa              nan
# 4             Blood & Water   South Africa              nan
# ...                     ...            ...              ...
# 89410                Zubaan          India      Mozez Singh
# 89411                Zubaan          India      Mozez Singh
# 89412                Zubaan          India      Mozez Singh
# 89413                Zubaan          India      Mozez Singh
# 89414                Zubaan          India      Mozez Singh
#
#                        actors show_id     type          date_added  \
# 0                         nan      s1    Movie  September 25, 2021
# 1                  Ama Qamata      s2  TV Show  September 24, 2021
# ...

# %%
constraint = df["listed_in"].apply(lambda x: str(x).split(",")).tolist()
df_genre = pd.DataFrame(constraint, index = df["title"])
df_genre = df_genre.stack()
df_genre = pd.DataFrame(df_genre.reset_index())
df_genre= df_genre.rename(columns = {0:"genre"})
df_genre.drop(["level_1"], axis = 1, inplace = True)
df_genre
# Out:
#                       title                     genre
# 0      Dick Johnson Is Dead             Documentaries
# 1             Blood & Water    International TV Shows
# 2             Blood & Water                 TV Dramas
# 3             Blood & Water              TV Mysteries
# 4                 Ganglands            Crime TV Shows
# ...                     ...                       ...
# 19318                  Zoom  Children & Family Movies
# 19319                  Zoom                  Comedies
# 19320                Zubaan                    Dramas
# 19321                Zubaan      International Movies
# 19322                Zubaan          Music & Musicals
#
# [19323 rows x 2 columns]

# %%
df_final.columns
# Out:
# Index(['title', 'Country', 'Director', 'actors', 'show_id', 'type',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df_final = df_genre.merge(df_final[['title', 'Country', 'Director', 'actors', 'show_id', 'type',
       'date_added', 'release_year', 'rating', 'duration', 'listed_in']], on=["title"], how ="left")
df_final
# Out:
#                        title                   genre        Country  \
# 0       Dick Johnson Is Dead           Documentaries  United States
# 1              Blood & Water  International TV Shows   South Africa
# 2              Blood & Water  International TV Shows   South Africa
# 3              Blood & Water  International TV Shows   South Africa
# 4              Blood & Water  International TV Shows   South Africa
# ...                      ...                     ...            ...
# 202060                Zubaan        Music & Musicals          India
# 202061                Zubaan        Music & Musicals          India
# 202062                Zubaan        Music & Musicals          India
# 202063                Zubaan        Music & Musicals          India
# 202064                Zubaan        Music & Musicals          India
#
#                Director                  actors show_id     type  \
# 0       Kirsten Johnson                     nan      s1    Movie
# ...

# %%
df_final.drop("listed_in", axis = 1, inplace =True)
df_final
# Out:
#                        title                   genre        Country  \
# 0       Dick Johnson Is Dead           Documentaries  United States
# 1              Blood & Water  International TV Shows   South Africa
# 2              Blood & Water  International TV Shows   South Africa
# 3              Blood & Water  International TV Shows   South Africa
# 4              Blood & Water  International TV Shows   South Africa
# ...                      ...                     ...            ...
# 202060                Zubaan        Music & Musicals          India
# 202061                Zubaan        Music & Musicals          India
# 202062                Zubaan        Music & Musicals          India
# 202063                Zubaan        Music & Musicals          India
# 202064                Zubaan        Music & Musicals          India
#
#                Director                  actors show_id     type  \
# 0       Kirsten Johnson                     nan      s1    Movie
# ...

# %%
df_final["date_added"] = pd.to_datetime(df_final["date_added"])
df_final["month_added"] = df_final["date_added"].dt.month_name()
df_final["year_added"] = df_final["date_added"].dt.year
df_final["day_of_week"] = df_final["date_added"].dt.day_name()
df_final
# Out:
#                        title                   genre        Country  \
# 0       Dick Johnson Is Dead           Documentaries  United States
# 1              Blood & Water  International TV Shows   South Africa
# 2              Blood & Water  International TV Shows   South Africa
# 3              Blood & Water  International TV Shows   South Africa
# 4              Blood & Water  International TV Shows   South Africa
# ...                      ...                     ...            ...
# 202060                Zubaan        Music & Musicals          India
# 202061                Zubaan        Music & Musicals          India
# 202062                Zubaan        Music & Musicals          India
# 202063                Zubaan        Music & Musicals          India
# 202064                Zubaan        Music & Musicals          India
#
#                Director                  actors show_id     type date_added  \
# ...

# %%
df_final.isnull().sum()
# Out:
# title             0
# genre             0
# Country           0
# Director          0
# actors            0
# show_id           0
# type              0
# date_added      158
# release_year      0
# rating           67
# duration          3
# month_added     158
# year_added      158
# day_of_week     158
# dtype: int64

# %%
df_final.loc[df_final["duration"].isnull()]
# Out:
#                                        title   genre        Country  \
# 126582                       Louis C.K. 2017  Movies  United States
# 131648                 Louis C.K.: Hilarious  Movies  United States
# 131782  Louis C.K.: Live at the Comedy Store  Movies  United States
#
#           Director      actors show_id   type date_added  release_year  \
# 126582  Louis C.K.  Louis C.K.   s5542  Movie 2017-04-04          2017
# 131648  Louis C.K.  Louis C.K.   s5795  Movie 2016-09-16          2010
# 131782  Louis C.K.  Louis C.K.   s5814  Movie 2016-08-15          2015
#
#         rating duration month_added  year_added day_of_week
# 126582  74 min      NaN       April      2017.0     Tuesday
# 131648  84 min      NaN   September      2016.0      Friday
# 131782  66 min      NaN      August      2016.0      Monday

# %%
df_final.loc[126582,"duration"] = "74 min"
df_final.loc[131648,"duration"] = "84 min"
df_final.loc[131782,"duration"] = "66 min"

# %%
df_final.isnull().sum()
# Out:
# title             0
# genre             0
# Country           0
# Director          0
# actors            0
# show_id           0
# type              0
# date_added      158
# release_year      0
# rating           67
# duration          0
# month_added     158
# year_added      158
# day_of_week     158
# dtype: int64

# %%
df_final.loc[126582,"rating"] = df_final["rating"].mode()[0]
df_final.loc[131648,"rating"] = df_final["rating"].mode()[0]
df_final.loc[131782,"rating"] = df_final["rating"].mode()[0]

# %%
df_final.loc[[126582,131648,131782]]
# Out:
#                                        title   genre        Country  \
# 126582                       Louis C.K. 2017  Movies  United States
# 131648                 Louis C.K.: Hilarious  Movies  United States
# 131782  Louis C.K.: Live at the Comedy Store  Movies  United States
#
#           Director      actors show_id   type date_added  release_year rating  \
# 126582  Louis C.K.  Louis C.K.   s5542  Movie 2017-04-04          2017  TV-MA
# 131648  Louis C.K.  Louis C.K.   s5795  Movie 2016-09-16          2010  TV-MA
# 131782  Louis C.K.  Louis C.K.   s5814  Movie 2016-08-15          2015  TV-MA
#
#        duration month_added  year_added day_of_week
# 126582   74 min       April      2017.0     Tuesday
# 131648   84 min   September      2016.0      Friday
# 131782   66 min      August      2016.0      Monday

# %%
df_final["date_added"].fillna(df_final["date_added"].mode()[0], inplace=True)
df_final["year_added"].fillna(df_final["year_added"].mode()[0], inplace=True)
df_final["month_added"].fillna(df_final["month_added"].mode()[0], inplace=True)
df_final["day_of_week"].fillna(df_final["day_of_week"].mode()[0], inplace=True)
df_final["rating"].fillna(df_final["rating"].mode()[0], inplace=True)

# %%
df_final.isnull().sum()
# Out:
# title           0
# genre           0
# Country         0
# Director        0
# actors          0
# show_id         0
# type            0
# date_added      0
# release_year    0
# rating          0
# duration        0
# month_added     0
# year_added      0
# day_of_week     0
# dtype: int64

# %%
"nan" in df_final["title"].values
# Out:
# False

# %%
"nan" in df_final["genre"].values
# Out:
# False

# %%
"nan" in df_final["Country"].values
# Out:
# True

# %%
df_final["Country"].replace("nan","country unknown", regex = True, inplace = True)

# %%
"nan" in df_final["Director"].values
# Out:
# True

# %%
df_final["Director"].replace("nan","director unknown", regex = True, inplace = True)

# %%
"nan" in df_final["actors"].values
# Out:
# True

# %%
df_final["actors"].replace("nan","actor unknown", regex = True, inplace = True)

# %%
"nan" in df_final["duration"].values
# Out:
# False

# %%
df_final
# Out:
#                        title                   genre        Country  \
# 0       Dick Johnson Is Dead           Documentaries  United States
# 1              Blood & Water  International TV Shows   South Africa
# 2              Blood & Water  International TV Shows   South Africa
# 3              Blood & Water  International TV Shows   South Africa
# 4              Blood & Water  International TV Shows   South Africa
# ...                      ...                     ...            ...
# 202060                Zubaan        Music & Musicals          India
# 202061                Zubaan        Music & Musicals          India
# 202062                Zubaan        Music & Musicals          India
# 202063                Zubaan        Music & Musicals          India
# 202064                Zubaan        Music & Musicals          India
#
#                 Director                  actors show_id     type date_added  \
# ...

# %%
d1 = sns.countplot(data = df_final,
              y = "year_added")

# %%
fig = d1.get_figure()
fig.savefig('year_added_countplot.png')

# %%
d2 = sns.countplot(data = df_final,
              y = "month_added")

# %%
fig2 = d2.get_figure()
fig2.savefig('month_added_countplot.png')

# %%
d3 = sns.countplot(data = df_final,
              y = "day_of_week")

# %%
fig3 = d3.get_figure()
fig3.savefig('day_of_week_countplot.png')

# %%
plt.figure(figsize = (10,8))
d4 =sns.scatterplot(data = df_final,
                x = "year_added",
                 y = "release_year", color = "g")

# %%
fig4 = d4.get_figure()
fig4.savefig('year_compare_scatterplot.png')

# %%
plt.savefig('year_added_countplot.png')

# %%
plt.figure(figsize = (15,8))
d5 = sns.countplot(data=df_final,
          x='year_added',
          hue='type')

# %%
fig5 = d5.get_figure()
fig5.savefig('year_type_relation_countplot.png')

# %%
d6 = sns.heatmap(df_final.corr(),annot = True)

# %%
fig6 = d6.get_figure()
fig6.savefig('heatplot.png')

# %%
plt.figure(figsize = (10,10))
d7 = sns.boxplot(data = df_final,
            x = "type",
            y = "year_added")

# %%
fig7 = d7.get_figure()
fig7.savefig('year_type_relation_boxplot.png')

# %%
d8 = sns.boxplot(data = df_final,
            x = "type",
            y = "release_year")

# %%
fig8 = d8.get_figure()
fig8.savefig('release_year_type_boxplot.png')

# %%
plt.figure(figsize = (25,8))
d9 = sns.boxplot(data = df_final,
            hue = "type",
            x = "release_year",
            y = "year_added")

# %%
plt.figure(figsize = (20,10))
d10 = sns.pairplot(data = df_final,
             hue ="type")

# %%
plt.figure(figsize=(10,10))
d11 = sns.countplot(data = df_final,
              x = "type",
              hue = "rating")

# %%
fig11 = d11.get_figure()
fig11.savefig('rating_type_countplot.png')

# %%
df_final["duration"].value_counts()
# Out:
# 1 Season     35035
# 2 Seasons     9559
# 3 Seasons     5084
# 94 min        4343
# 106 min       4040
#              ...
# 3 min            4
# 5 min            3
# 11 min           2
# 8 min            2
# 9 min            2
# Name: duration, Length: 220, dtype: int64

# %%
df_final["Country"].value_counts()
# Out:
# United States      49868
# India              22139
# country unknown    11897
# United Kingdom      9733
#  United States      9482
#                    ...
#  Samoa                 2
#  Sri Lanka             2
#  Kazakhstan            1
#  Uganda                1
#  Nicaragua             1
# Name: Country, Length: 198, dtype: int64

# %%
df_final["Director"].value_counts()
# Out:
# director unknown       50643
# Martin Scorsese          419
# Youssef Chahine          409
# Cathy Garcia-Molina      356
# Steven Spielberg         355
#                        ...
#  Reuben Atlas              1
# Max Amini                  1
# Bassam Tariq               1
# Paul Miller                1
# Kirsten Johnson            1
# Name: Director, Length: 5121, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
a = df_final.loc[df_final["Director"] == "Martin Scorsese", ["title","Country"]]

# %%
a.value_counts()
# Out:
# title                                                        Country
# Hugo                                                          United States    38
#                                                              United Kingdom    38
#                                                               France           38
# Alice Doesn't Live Here Anymore                              United States     30
# Raging Bull                                                  United States     27
# Who's That Knocking at My Door?                              United States     27
# Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese  United States     26
# Mean Streets                                                 United States     24
# GoodFellas                                                   United States     20
# No Direction Home: Bob Dylan                                  Japan            20
#                                                              United Kingdom    20
# ...

# %%
b = df_final.loc[df_final["Country"] == "India", ["Country","genre"]]

# %%
b.value_counts()
# Out:
# Country  genre
# India     International Movies            6619
#          Dramas                           3365
#          Comedies                         2205
#           Dramas                          2035
#           Independent Movies              1345
#          Action & Adventure               1121
#           Romantic Movies                  931
#           Music & Musicals                 819
#           Thrillers                        733
#           Comedies                         411
#          International TV Shows            349
#          International Movies              291
#           TV Dramas                        272
#          Horror Movies                     271
#          TV Shows                          207
#          Children & Family Movies          165
#           TV Comedies                      141
#           Sports Movies                    110
#           Sci-Fi & Fantasy                  85
#          Classic Movies                     80
# ...

# %%
df_final["actors"].value_counts()
# Out:
# actor unknown            2149
#  Alfred Molina            160
#  Salma Hayek              130
#  Frank Langella           128
#  John Rhys-Davies         125
#                          ...
#  Cle Sloan                  1
#  George Konner              1
#  Andy Hayward               1
#  Lyric Lewis                1
#  Trent 'Maxi' Maxwell       1
# Name: actors, Length: 39297, dtype: int64

# %%
c = df_final.loc[df_final["Country"] == "India", ["Country","actors"]]

# %%
c.value_counts()
# Out:
# Country  actors
# India     Anupam Kher      102
#           Radhika Apte      80
#          actor unknown      77
#           Paresh Rawal      73
#          Shah Rukh Khan     73
#                           ...
#           Cole Howard        1
#           Katie Leigh        1
#          Revathi             1
#           Alan Marriott      1
#          Emma Tate           1
# Length: 4034, dtype: int64

# %%
d = df_final.loc[df_final["Country"] == "India", ["Country","type"]]

# %%
d.value_counts()
# Out:
# Country  type
# India    Movie      20761
#          TV Show     1378
# dtype: int64

# %%
d1 = df_final.loc[df_final["Country"] == "India", ["Country","year_added"]]
d1.value_counts()
# Out:
# Country  year_added
# India    2018.0        7316
#          2019.0        4487
#          2020.0        4270
#          2017.0        3228
#          2021.0        2423
#          2016.0         415
# dtype: int64

# %%
d2 = df_final.loc[df_final["Country"] == "India", ["Country","month_added"]]
d2.value_counts()
# Out:
# Country  month_added
# India    December       2640
#          August         2349
#          March          2335
#          April          2291
#          October        2266
#          July           2032
#          November       1944
#          September      1463
#          January        1404
#          May            1241
#          February       1210
#          June            964
# dtype: int64

# %%
d3 = df_final.loc[df_final["Country"] == "India", ["Country","day_of_week"]]
d3.value_counts()
# Out:
# Country  day_of_week
# India    Thursday       4663
#          Friday         4311
#          Monday         3361
#          Sunday         3109
#          Tuesday        2553
#          Wednesday      2372
#          Saturday       1770
# dtype: int64

# %%
d4 = df_final.loc[df_final["Country"] == "India", ["Country","Director"]]
d4.value_counts()
# Out:
# Country  Director
# India    director unknown      977
#          David Dhawan          270
#          Sooraj R. Barjatya    180
#          Anurag Kashyap        171
#          Ram Gopal Varma       158
#                               ...
#          Kireet Khurana          2
#           Ajay Bhuyan            1
#          Angshuman Ghosh         1
#          Fazila Allana           1
#          Neville Shah            1
# Length: 718, dtype: int64

# %%
d5 = df_final.loc[df_final["Country"] == "India", ["Country","genre"]]
d5.value_counts()
# Out:
# Country  genre
# India     International Movies            6619
#          Dramas                           3365
#          Comedies                         2205
#           Dramas                          2035
#           Independent Movies              1345
#          Action & Adventure               1121
#           Romantic Movies                  931
#           Music & Musicals                 819
#           Thrillers                        733
#           Comedies                         411
#          International TV Shows            349
#          International Movies              291
#           TV Dramas                        272
#          Horror Movies                     271
#          TV Shows                          207
#          Children & Family Movies          165
#           TV Comedies                      141
#           Sports Movies                    110
#           Sci-Fi & Fantasy                  85
#          Classic Movies                     80
# ...

# %%
d6 = df_final.loc[df_final["Country"] == "India", ["Country","duration"]]
d6.value_counts()
# Out:
# Country  duration
# India    1 Season    1276
#          137 min      553
#          131 min      539
#          127 min      532
#          121 min      506
#                      ...
#          76 min         2
#          58 min         2
#          52 min         2
#          29 min         2
#          50 min         1
# Length: 130, dtype: int64

# %%
df_final.sort_values(["release_year"], ascending = False)
# Out:
#                                     title                    genre  \
# 6747                       I Need Romance              TV Comedies
# 18563                               Lupin   International TV Shows
# 18486          Cobra Kai - The Afterparty                   Movies
# 18487     Love (ft. Marriage and Divorce)   International TV Shows
# 18488     Love (ft. Marriage and Divorce)   International TV Shows
# ...                                   ...                      ...
# 187543               The Battle of Midway            Documentaries
# 177451                     Prelude to War           Classic Movies
# 177452                     Prelude to War            Documentaries
# 187542               The Battle of Midway            Documentaries
# 99245   Pioneers: First Women Filmmakers*                 TV Shows
#
#                 Country          Director                  actors show_id  \
# 6747    country unknown  Sakon Tiacharoen   Katareeya Theapchatri    s288
# ...

# %%
df_final["year_added"].value_counts()
# Out:
# 2019.0    47155
# 2020.0    46051
# 2021.0    36534
# 2018.0    35785
# 2017.0    25209
# 2016.0     8569
# 2015.0     1560
# 2014.0      452
# 2011.0      438
# 2013.0      207
# 2012.0       36
# 2009.0       30
# 2010.0       20
# 2008.0       19
# Name: year_added, dtype: int64

# %%
df_final["release_year"].value_counts()
# Out:
# 2018    24441
# 2019    21931
# 2017    20516
# 2020    19697
# 2016    18465
#         ...
# 1947        8
# 1946        6
# 1942        6
# 1943        5
# 1925        1
# Name: release_year, Length: 74, dtype: int64

# %%
df_final["type"].value_counts()
# Out:
# Movie      145917
# TV Show     56148
# Name: type, dtype: int64

# %%
df_final["genre"].value_counts()
# Out:
#  International Movies    27141
# Dramas                   19657
# Comedies                 13894
# Action & Adventure       12216
#  Dramas                  10149
#                          ...
#  Stand-Up Comedy            24
# Romantic Movies             20
# TV Sci-Fi & Fantasy          7
# LGBTQ Movies                 5
# Sports Movies                3
# Name: genre, Length: 73, dtype: int64

# %%
df_final["Country"].value_counts()
# Out:
# United States      49868
# India              22139
# country unknown    11897
# United Kingdom      9733
#  United States      9482
#                    ...
#  Samoa                 2
#  Sri Lanka             2
#  Kazakhstan            1
#  Uganda                1
#  Nicaragua             1
# Name: Country, Length: 198, dtype: int64
